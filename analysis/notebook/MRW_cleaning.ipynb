# %% [markdown]
# # Setup

# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
from thefuzz import fuzz
from thefuzz import process

# %% [markdown]
# # Load data

# %%
MRW = pd.read_excel('../data/MRW.xlsx', sheet_name=[0, 1, 2, 3, 4])
MRWT, MRWGP, MRWSKU, MRWU, MRWER = MRW[0], MRW[1], MRW[2], MRW[3], MRW[4]

# %% [markdown]
# # MRWT

# %%
MRWT
# Out:
#        Distributor                 ProductName              ProductSKU  \
# 0                B  Mobil Super AIO - Charcoal    Mobil Super AIO - 7L
# 1                B  Mobil Super AIO - Charcoal    Mobil Super AIO - 7L
# 2                B  Mobil Super AIO - Charcoal    Mobil Super AIO - 7L
# 3                B  Mobil Super AIO - Charcoal    Mobil Super AIO - 7L
# 4                B  Mobil Super AIO - Charcoal    Mobil Super AIO - 7L
# ...            ...                         ...                     ...
# 215651           C              Mobil Super FF  Mobil Super FF 4L - 7L
# 215652           C              Mobil Super FF  Mobil Super FF 4L - 7L
# 215653           C              Mobil Super FF  Mobil Super FF 4L - 7L
# 215654           C              Mobil Super FF  Mobil Super FF 4L - 7L
# 215655           C              Mobil Super FF  Mobil Super FF 4L - 7L
#
#          ScanDate             UserId
# 0      2023-11-29  EXL_1692444744991
# 1      2023-11-29  EXL_1692444744991
# 2      2023-11-29  EXL_1692444744991
# 3      2023-11-29  EXL_1692444744991
# 4      2023-11-29  EXL_1692444744991
# ...           ...                ...
# 215651 2023-06-19  EXL_1686836958772
# 215652 2023-06-19  EXL_1686836958772
# 215653 2023-06-19  EXL_1686836958772
# 215654 2023-06-15  EXL_1686836958772
# 215655 2023-06-15  EXL_1686836958772
#
# [215656 rows x 5 columns]

# %%
MRWT.dtypes
# Out:
# Distributor            object
# ProductName            object
# ProductSKU             object
# ScanDate       datetime64[ns]
# UserId                 object
# dtype: object

# %% [markdown]
# ## Check null (general)

# %%
MRWT.isna().any()
# Out:
# Distributor    False
# ProductName    False
# ProductSKU     False
# ScanDate       False
# UserId         False
# dtype: bool

# %% [markdown]
# There is indeed duplicated, no need to check

# %% [markdown]
# ## Distributor

# %%
MRWT['Distributor'].unique()
# Out:
# array(['B', 'A', 'C', 'D'], dtype=object)

# %% [markdown]
# ## ProductName

# %%
MRWT['ProductName'].unique()
# Out:
# array(['Mobil Super AIO - Charcoal', 'Mobil Super FF',
#        'Mobil Delvac Modern', 'Mobil Super AIO', 'Mobil Delvac Legend',
#        'Mobil 1 Gold', 'Silver Large', 'Blue Large', 'Gold Large'],
#       dtype=object)

# %% [markdown]
# ## ProductSKU

# %%
len(MRWT['ProductSKU'].unique())
#MRWT.groupby(['ProductName', 'ProductSKU']).count() #!!!
# Out:
# 10

# %% [markdown]
# ## ProductSKU (SKU)

# %%
len(MRWSKU['ProductSKU'].unique())
# Out:
# 10

# %% [markdown]
# ## ScanDate

# %%
MRWTScanDateMin = MRWT['ScanDate'].min()
MRWTSCanDateMax = MRWT['ScanDate'].max()
print(f"min:{MRWTScanDateMin}, max:{MRWTSCanDateMax}")
# Out:
# min:2023-01-01 00:00:00, max:2023-12-31 00:00:00

# %% [markdown]
# ## UserId

# %%
MRWTUserIdCount = len(MRWT['UserId'].unique())
MRWTUserIdMin = MRWT['UserId'].min()
MRWTUserIdMax = MRWT['UserId'].max()
print(f"Count:{MRWTUserIdCount}, min:{MRWTUserIdMin}, max:{MRWTUserIdMax}")
# Out:
# Count:1428, min:EXL_1569867483497, max:EXL_1703840783686

# %% [markdown]
# ## OwnerId (Garage Profile)

# %%
MRWGPUserIdCount = len(MRWGP['OwnerId'].unique())
MRWGPUserIdMin = MRWGP['OwnerId'].min()
MRWGPUserIdMax = MRWGP['OwnerId'].max()
print(f"Count:{MRWGPUserIdCount}, min:{MRWGPUserIdMin}, max:{MRWGPUserIdMax}")
# Out:
# Count:4006, min:EXL_1569434212261, max:EXL_1703844536464

# %% [markdown]
# ## Postcode (Garage Profile)

# %%
MRWGP['Postcode'].unique()

# there is a white space after District!!
MRWGP.rename(columns={"District ": "District"}, inplace=True)

# convert postcode to int
MRWGP["Postcode"] = MRWGP["Postcode"].astype(pd.Int64Dtype())

# scenario: postcode exist but district is missing
MRWGP[(MRWGP['Postcode'].notna()) & (MRWGP['District'] == "เขต")]
# Out:
#                 OwnerId  Postcode         Province District Distributor
# 100   EXL_1657555803230     64000          สุโขทัย      เขต           C
# 191   EXL_1576587181605     11000          นนทบุรี      เขต           A
# 348   EXL_1573049265095     11000          นนทบุรี      เขต           A
# 361   EXL_1572691481498     11000          นนทบุรี      เขต           A
# 481   EXL_1579261368753     11000          นนทบุรี      เขต           A
# 680   EXL_1605709537255     60000        นครสวรรค์      เขต           C
# 1009  EXL_1700227450476     64000          สุโขทัย      เขต           C
# 1097  EXL_1601549347440     60000        นครสวรรค์      เขต           C
# 1140  EXL_1575643636201     60000        นครสวรรค์      เขต           C
# 1456  EXL_1585064765189     60000        นครสวรรค์      เขต           C
# 1572  EXL_1654771506905     90000            สงขลา      เขต           D
# 1761  EXL_1573739016133     11000          นนทบุรี      เขต           A
# 1842  EXL_1571927661589     20140           ชลบุรี      เขต           A
# 1861  EXL_1658232982620     44000        มหาสารคาม      เขต           A
# 1869  EXL_1570024989612     92140             ตรัง      เขต           D
# 2069  EXL_1694685410503     11100          นนทบุรี      เขต           A
# 2084  EXL_1588689224817     60240        นครสวรรค์      เขต           C
# 2108  EXL_1636369141995     90110            สงขลา      เขต           D
# 2331  EXL_1571833053662     77120  ประจวบคีรีขันธ์      เขต           B
# 2340  EXL_1571838528259     51120            ลำพูน      เขต           C
# 2368  EXL_1570605802952     60000        นครสวรรค์      เขต           C
# 2371  EXL_1591368490701     60000        นครสวรรค์      เขต           C
# 2622  EXL_1602327840711     60000        นครสวรรค์      เขต           C
# 2859  EXL_1605878498947     60240        นครสวรรค์      เขต           C
# 2992  EXL_1574178880751     60000        นครสวรรค์      เขต           C
# 3052  EXL_1573141507772     11120          นนทบุรี      เขต           A
# 3082  EXL_1572011763656     18110          สระบุรี      เขต           A
# 3120  EXL_1570543489097     77110  ประจวบคีรีขันธ์      เขต           B
# 3220  EXL_1571228196275     10540      สมุทรปราการ      เขต           A
# 3392  EXL_1643890031323     65220         พิษณุโลก      เขต           C
# 3405  EXL_1571316664992     11000          นนทบุรี      เขต           A
# 3574  EXL_1699445012810     52000            ลำปาง      เขต           C
# 3838  EXL_1572607494920     60000        นครสวรรค์      เขต           C
# 3997  EXL_1686836958772     57000         เชียงราย      เขต           C

# %%
# https://github.com/rathpanyowat/Thai-zip-code-latitude-and-longitude/blob/master/data.json

postcode = pd.read_excel("../data/PostcodeData.xlsx")
postcode['district'] = "เขต" + postcode['district']

postcodeDict = postcode[["zip", "district"]].set_index("zip").to_dict()['district']

# %%
#MRWGP.loc[(MRWGP['Postcode'].notna()) & (MRWGP['District'] == "เขต"), "District"]
MRWGP[(MRWGP['Postcode'].notna()) & (MRWGP['District'] == "เขต")]["Postcode"]

def findDistrict(record):
    if record not in postcodeDict:
        return np.nan
    
    return postcodeDict[record]

districtLabel = MRWGP[(MRWGP['Postcode'].notna()) & (MRWGP['District'] == "เขต")]["Postcode"].apply(findDistrict)
MRWGP.loc[(MRWGP['Postcode'].notna()) & (MRWGP['District'] == "เขต"), "District"] = districtLabel
MRWGP[(MRWGP['Postcode'].notna()) & (MRWGP['District'].isna())] # can not be filled, wait there is only one!
# Out:
#                 OwnerId  Postcode Province District Distributor
# 2069  EXL_1694685410503     11100  นนทบุรี      NaN           A

# %%
 # apprently there are alreay this postcode in the data and it correspond to this district name
MRWGP.loc[MRWGP['Postcode'] == 11100, 'District'] = "เขตเมืองนนทบุรี"  
MRWGP[(MRWGP['Postcode'].notna()) & (MRWGP['District'].isna())]
# Out:
# Empty DataFrame
# Columns: [OwnerId, Postcode, Province, District, Distributor]
# Index: []

# %% [markdown]
# Since we will be using districtname we will not continute cleaning postcode

# %% [markdown]
# ## Province (Garage Profile)

# %%
MRWGP['Province'].unique()
# Out:
# array(['สุพรรณบุรี', 'เชียงราย', 'กรุงเทพมหานคร', 'สมุทรปราการ',
#        'นครราชสีมา', 'พิษณุโลก', 'ระยอง', 'ชลบุรี', 'ปทุมธานี',
#        'เชียงใหม่', 'ขอนแก่น', 'ภูเก็ต', 'สระบุรี', 'สมุทรสาคร',
#        'นนทบุรี', 'สุราษฎร์ธานี', 'พัทลุง', 'สมุทรสงคราม', 'กำแพงเพชร',
#        'นครสวรรค์', 'อุตรดิตถ์', 'ตราด', 'ชัยนาท', 'นครปฐม', 'ราชบุรี',
#        'สระแก้ว', 'นครศรีธรรมราช', 'พระนครศรีอยุธยา', 'ศรีสะเกษ',
#        'ฉะเชิงเทรา', 'อุบลราชธานี', 'อุดรธานี', 'สุโขทัย', 'น่าน',
#        'เพชรบูรณ์', 'สิงห์บุรี', 'เพชรบุรี', 'พังงา', 'พิจิตร',
#        'จันทบุรี', 'ประจวบคีรีขันธ์', 'พะเยา', 'กระบี่', 'บึงกาฬ',
#        'ลำปาง', 'ตรัง', 'สงขลา', 'ลำพูน', 'แพร่', 'บุรีรัมย์', 'เลย',
#        'ยโสธร', 'ลพบุรี', 'ปราจีนบุรี', 'อำนาจเจริญ', 'สุรินทร์',
#        'สกลนคร', 'ชุมพร', 'ร้อยเอ็ด', 'ปัตตานี', 'นครพนม', 'หนองคาย',
#        'ชัยภูมิ', 'กาฬสินธุ์', 'นครนายก', 'ตาก', 'ระนอง', 'มหาสารคาม',
#        'แม่ฮ่องสอน', 'กาญจนบุรี', 'หนองบัวลำภู', 'มุกดาหาร', 'อุทัยธานี',
#        'ยะลา', 'นราธิวาส', 'อ่างทอง', 'สตูล'], dtype=object)

# %% [markdown]
# ## District (Garage Profile)

# %%
MRWGP.loc[MRWGP['District'] == "เขต", 'District'] = np.nan # just flag it as null
MRWGP[MRWGP['District'].isna()] # there is nothing we can do bro
# Out:
#                 OwnerId  Postcode       Province District Distributor
# 643   EXL_1627239745637      <NA>  กรุงเทพมหานคร      NaN           A
# 735   EXL_1676365474904      <NA>  กรุงเทพมหานคร      NaN           A
# 1088  EXL_1570717772373      <NA>       เชียงราย      NaN           C
# 1113  EXL_1684409855383      <NA>  กรุงเทพมหานคร      NaN           A
# 1524  EXL_1662127146907      <NA>      เพชรบูรณ์      NaN           C
# 1547  EXL_1663447911873      <NA>  กรุงเทพมหานคร      NaN           A
# 1579  EXL_1594294562047      <NA>         ภูเก็ต      NaN           D
# 1596  EXL_1652786934570      <NA>  กรุงเทพมหานคร      NaN           A
# 1688  EXL_1592653287874      <NA>        ราชบุรี      NaN           B
# 2370  EXL_1643035798677      <NA>       ศรีสะเกษ      NaN           A
# 2394  EXL_1663334976311      <NA>     สุพรรณบุรี      NaN           B
# 2575  EXL_1576246135401      <NA>        ราชบุรี      NaN           B
# 2629  EXL_1688736805946      <NA>  กรุงเทพมหานคร      NaN           A
# 2753  EXL_1573043600600      <NA>  กรุงเทพมหานคร      NaN           A
# 2862  EXL_1661600407491      <NA>       มุกดาหาร      NaN           A
# 2957  EXL_1624642477499      <NA>       พิษณุโลก      NaN           C
# 2993  EXL_1678793082714      <NA>           น่าน      NaN           C
# 3111  EXL_1650729033703      <NA>        สระบุรี      NaN           A
# 3276  EXL_1646319967524      <NA>       มุกดาหาร      NaN           A
# 3800  EXL_1658237820517      <NA>  กรุงเทพมหานคร      NaN           A
# 3897  EXL_1585825962935      <NA>  กรุงเทพมหานคร      NaN           A

# %% [markdown]
# ## Points/Bottle (ProductSKU)

# %%
MRWSKU['Points']
# Out:
# 0    60
# 1    50
# 2    50
# 3    45
# 4    40
# 5    40
# 6    35
# 7    20
# 8    15
# 9    10
# Name: Points, dtype: int64

# %% [markdown]
# ## Volume (ProductSKU)

# %%
MRWSKU['Volume (L)']
# Out:
# 0    6
# 1    4
# 2    4
# 3    7
# 4    5
# 5    5
# 6    6
# 7    7
# 8    5
# 9    7
# Name: Volume (L), dtype: int64

# %% [markdown]
# ## GarageId (User)

# %%
MRWU['GarageId'].isna().any()
MRWUGarIdMin = MRWU['GarageId'].min()
MRWUGarIdMax = MRWU['GarageId'].max()
print(f"min: {MRWUGarIdMin}, max:{MRWUGarIdMax}")
# Out:
# min: AA3539, max:ZZ9482

# %% [markdown]
# ## UserType (User)

# %%
MRWU['UserType'].unique()
# Out:
# array(['Owner', 'Employee'], dtype=object)

# %% [markdown]
# # Join time!

# %% [markdown]
# ## Prepare Table

# %% [markdown]
# ### MRWT

# %%
cols = MRWT.columns.values.tolist()
MRWT = MRWT.groupby(cols).size().reset_index().rename(columns={0: "Count"})
MRWT
# Out:
#       Distributor   ProductName            ProductSKU   ScanDate  \
# 0               A    Blue Large  Blue - Large 4L - 5L 2023-01-04
# 1               A    Blue Large  Blue - Large 4L - 5L 2023-01-17
# 2               A    Blue Large  Blue - Large 4L - 5L 2023-03-01
# 3               A    Blue Large  Blue - Large 4L - 5L 2023-05-03
# 4               A    Blue Large  Blue - Large 4L - 5L 2023-06-15
# ...           ...           ...                   ...        ...
# 36010           D  Silver Large     Silver - Large 4L 2023-12-26
# 36011           D  Silver Large     Silver - Large 4L 2023-12-26
# 36012           D  Silver Large     Silver - Large 4L 2023-12-27
# 36013           D  Silver Large     Silver - Large 4L 2023-12-28
# 36014           D  Silver Large     Silver - Large 4L 2023-12-30
#
#                   UserId  Count
# 0      EXL_1573744836492      2
# 1      EXL_1573744836492      1
# 2      EXL_1573744836492      1
# 3      EXL_1619694294901      1
# 4      EXL_1592832015021      1
# ...                  ...    ...
# 36010  EXL_1636202798697      4
# 36011  EXL_1691757071956      1
# 36012  EXL_1691757071956      2
# 36013  EXL_1691757071956      1
# 36014  EXL_1691757071956      2
#
# [36015 rows x 6 columns]

# %% [markdown]
# ### MRWU

# %%
MRWU
# Out:
#                  UserId GarageId  UserType
# 0     EXL_1569429819465   TX4276     Owner
# 1     EXL_1569431062769   IP0146     Owner
# 2     EXL_1569431134633   AF0708  Employee
# 3     EXL_1569431146924   TX4276  Employee
# 4     EXL_1569432034271   TX4276  Employee
# ...                 ...      ...       ...
# 4714  EXL_1716585305340   TX6300     Owner
# 4715  EXL_1716824732478   RS5281     Owner
# 4716  EXL_1717078601618   QY6868     Owner
# 4717  EXL_1717153057699   AN6271     Owner
# 4718  EXL_1717154739687   XZ5536     Owner
#
# [4719 rows x 3 columns]

# %%
(MRWU[MRWU['UserType'] == "Owner"].groupby("GarageId").count() == 1).all() #One GarageId has one Owner
# Out:
# UserId      True
# UserType    True
# dtype: bool

# %%
GarageIdToOwner = MRWU[MRWU['UserType'] == "Owner"].set_index("GarageId")['UserId']
MRUW = MRWU.set_index("GarageId").join(GarageIdToOwner, rsuffix="Owner").reset_index()
# check
(MRUW[MRUW['UserType'] == "Owner"]["UserId"] == MRUW[MRUW['UserType'] == "Owner"]["UserId"]).all() #alright
MRUW
# Out:
#      GarageId             UserId  UserType        UserIdOwner
# 0      TX4276  EXL_1569429819465     Owner  EXL_1569429819465
# 1      IP0146  EXL_1569431062769     Owner  EXL_1569431062769
# 2      AF0708  EXL_1569431134633  Employee  EXL_1569921668308
# 3      TX4276  EXL_1569431146924  Employee  EXL_1569429819465
# 4      TX4276  EXL_1569432034271  Employee  EXL_1569429819465
# ...       ...                ...       ...                ...
# 4714   TX6300  EXL_1716585305340     Owner  EXL_1716585305340
# 4715   RS5281  EXL_1716824732478     Owner  EXL_1716824732478
# 4716   QY6868  EXL_1717078601618     Owner  EXL_1717078601618
# 4717   AN6271  EXL_1717153057699     Owner  EXL_1717153057699
# 4718   XZ5536  EXL_1717154739687     Owner  EXL_1717154739687
#
# [4719 rows x 4 columns]

# %%
MRWUserWithGarage = MRUW.set_index("UserIdOwner").join(MRWGP.set_index("OwnerId")).reset_index().drop(columns="Distributor")

# %%
# join transaction with sku
MRWT = MRWT.set_index("ProductSKU").join(MRWSKU.set_index("ProductSKU")).reset_index()
MRWT
# Out:
#                  ProductSKU Distributor   ProductName   ScanDate  \
# 0      Blue - Large 4L - 5L           A    Blue Large 2023-01-04
# 1      Blue - Large 4L - 5L           A    Blue Large 2023-01-17
# 2      Blue - Large 4L - 5L           A    Blue Large 2023-03-01
# 3      Blue - Large 4L - 5L           A    Blue Large 2023-05-03
# 4      Blue - Large 4L - 5L           A    Blue Large 2023-06-15
# ...                     ...         ...           ...        ...
# 36010     Silver - Large 4L           D  Silver Large 2023-12-26
# 36011     Silver - Large 4L           D  Silver Large 2023-12-26
# 36012     Silver - Large 4L           D  Silver Large 2023-12-27
# 36013     Silver - Large 4L           D  Silver Large 2023-12-28
# 36014     Silver - Large 4L           D  Silver Large 2023-12-30
#
#                   UserId  Count  Points  Volume (L)
# 0      EXL_1573744836492      2      15           5
# 1      EXL_1573744836492      1      15           5
# 2      EXL_1573744836492      1      15           5
# 3      EXL_1619694294901      1      15           5
# 4      EXL_1592832015021      1      15           5
# ...                  ...    ...     ...         ...
# 36010  EXL_1636202798697      4      50           4
# 36011  EXL_1691757071956      1      50           4
# 36012  EXL_1691757071956      2      50           4
# 36013  EXL_1691757071956      1      50           4
# 36014  EXL_1691757071956      2      50           4
#
# [36015 rows x 8 columns]

# %%
# join with UserWithGarage
MRWT = MRWT.set_index("UserId").join(MRWUserWithGarage.set_index("UserId")).reset_index()

# %%
MRWT
# Out:
#                   UserId            ProductSKU Distributor   ProductName  \
# 0      EXL_1573744836492  Blue - Large 4L - 5L           A    Blue Large
# 1      EXL_1573744836492  Blue - Large 4L - 5L           A    Blue Large
# 2      EXL_1573744836492  Blue - Large 4L - 5L           A    Blue Large
# 3      EXL_1619694294901  Blue - Large 4L - 5L           A    Blue Large
# 4      EXL_1592832015021  Blue - Large 4L - 5L           A    Blue Large
# ...                  ...                   ...         ...           ...
# 36010  EXL_1636202798697     Silver - Large 4L           D  Silver Large
# 36011  EXL_1691757071956     Silver - Large 4L           D  Silver Large
# 36012  EXL_1691757071956     Silver - Large 4L           D  Silver Large
# 36013  EXL_1691757071956     Silver - Large 4L           D  Silver Large
# 36014  EXL_1691757071956     Silver - Large 4L           D  Silver Large
#
#         ScanDate  Count  Points  Volume (L)        UserIdOwner GarageId  \
# 0     2023-01-04      2      15           5  EXL_1573744836492   BC0891
# 1     2023-01-17      1      15           5  EXL_1573744836492   BC0891
# 2     2023-03-01      1      15           5  EXL_1573744836492   BC0891
# 3     2023-05-03      1      15           5  EXL_1619694294901   WO0982
# 4     2023-06-15      1      15           5  EXL_1592832015021   JE4271
# ...          ...    ...     ...         ...                ...      ...
# 36010 2023-12-26      4      50           4  EXL_1636202798697   QS3164
# 36011 2023-12-26      1      50           4  EXL_1691757071956   IB0726
# 36012 2023-12-27      2      50           4  EXL_1691757071956   IB0726
# 36013 2023-12-28      1      50           4  EXL_1691757071956   IB0726
# 36014 2023-12-30      2      50           4  EXL_1691757071956   IB0726
#
#       UserType  Postcode       Province      District
# 0        Owner     10260  กรุงเทพมหานคร      เขตบางนา
# 1        Owner     10260  กรุงเทพมหานคร      เขตบางนา
# 2        Owner     10260  กรุงเทพมหานคร      เขตบางนา
# 3        Owner     10510  กรุงเทพมหานคร  เขตคลองสามวา
# 4        Owner     10540    สมุทรปราการ     เขตบางพลี
# ...        ...       ...            ...           ...
# 36010    Owner     90110          สงขลา    เขตหาดใหญ่
# 36011    Owner     93110         พัทลุง    เขตควนขนุน
# 36012    Owner     93110         พัทลุง    เขตควนขนุน
# 36013    Owner     93110         พัทลุง    เขตควนขนุน
# 36014    Owner     93110         พัทลุง    เขตควนขนุน
#
# [36015 rows x 14 columns]

# %%
MRWT.to_csv("../data/MRWCleaned.csv")
