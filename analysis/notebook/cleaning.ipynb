# %% [markdown]
# # Setup

# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
from thefuzz import fuzz
from thefuzz import process

# %% [markdown]
# # MER

# %% [markdown]
# ## Load data

# %%
MER = pd.read_excel('../data/MER.xlsx', sheet_name=[0, 1])
MERT, MERPPL = MER[0], MER[1]

# %% [markdown]
# ### Column types

# %%
MERT.dtypes
MERPPL.dtypes
# Out:
# MatNo     int64
# Points    int64
# dtype: object

# %% [markdown]
# ### Check null (general)

# %%
isNullMERT = MERT.isna().any().any()
isNullMERPPL = MERPPL.isna().any().any()
print(f"MERT: {str(isNullMERT)}, MERPPL: {str(isNullMERPPL)}")
# Out:
# MERT: False, MERPPL: False

# %% [markdown]
# ### Check duplicated (general)

# %%
isDuplicatedMERT = MERT.duplicated().any()
isDuplicatedMERPPL = MERPPL.duplicated().any()

print(f"MERT: {str(isDuplicatedMERT)}, MERPPL: {str(isDuplicatedMERT)}")
# Out:
# MERT: False, MERPPL: False

# %% [markdown]
# ## Investigate columns

# %% [markdown]
# ### Invoicedate

# %%
dataType = str(MERT['Invoicedate'].dtypes)
invoicedateMin = MERT['Invoicedate'].min()
invoicedateMax = MERT['Invoicedate'].max()
print(f"Type: {dataType}, Min: {invoicedateMin}, Max:{invoicedateMax}")
# Out:
# Type: datetime64[ns], Min: 2023-01-03 00:00:00, Max:2023-12-29 00:00:00

# %% [markdown]
# The data is for the year 2023

# %% [markdown]
# ### Distrubutor

# %%
MERT['Distributor'].unique()
# Out:
# array(['A', 'B', 'C', 'D'], dtype=object)

# %% [markdown]
# ### GroupId

# %%
MERT['GroupId'].unique()
groupidMin = MERT['GroupId'].min()
groupidMax = MERT['GroupId'].max()
print(f"Min: {str(groupidMin)}, Max: {str(groupidMax)}")
# Out:
# Min: ERW_A1DS2023040002, Max: ERW_DYZP2023100001

# %% [markdown]
# ### Type

# %%
MERT['Type'].unique()
# Out:
# array(['Reseller', 'Retails'], dtype=object)

# %% [markdown]
# ### Provincename

# %%
MERT['Provincename'].unique() # found 'N\\A'
nullProvincename = MERT[MERT['Provincename'] == 'N\\A']['GroupId'].unique().tolist()
MERT[MERT['GroupId'].isin(nullProvincename)] # yep no way to fill this
# Out:
#      Invoicedate Distributor             GroupId     Type Provincename  \
# 1059  2023-12-15           A  ERW_A7QF2022060003  Retails          N\A
# 1771  2023-11-23           A  ERW_A7QF2022060003  Retails          N\A
# 2489  2023-11-23           A  ERW_A7QF2022060003  Retails          N\A
# 3191  2023-03-17           A  ERW_A6CM2022070002  Retails          N\A
# 3192  2023-07-21           A  ERW_A6CM2022070002  Retails          N\A
# 4427  2023-02-14           A  ERW_A7QF2022060003  Retails          N\A
# 4754  2023-12-15           A  ERW_A7QF2022060003  Retails          N\A
# 4954  2023-02-13           A  ERW_A7QF2022060003  Retails          N\A
# 5690  2023-05-08           B  ERW_BXEO2021030004  Retails          N\A
# 5805  2023-11-03           A  ERW_A7QF2022060002  Retails          N\A
# 6572  2023-10-26           A  ERW_A7QF2022060003  Retails          N\A
# 6692  2023-07-21           A  ERW_A6CM2022070002  Retails          N\A
# 6693  2023-10-26           A  ERW_A7QF2022060003  Retails          N\A
# 7084  2023-02-13           A  ERW_A7QF2022060003  Retails          N\A
# 7656  2023-07-21           A  ERW_A6CM2022070002  Retails          N\A
# 7657  2023-12-12           A  ERW_A7QF2022060003  Retails          N\A
# 7971  2023-01-27           A  ERW_A7QF2022060003  Retails          N\A
# 7972  2023-05-29           A  ERW_A7QF2022060003  Retails          N\A
# 8027  2023-02-13           A  ERW_A7QF2022060003  Retails          N\A
# 8321  2023-02-13           A  ERW_A7QF2022060003  Retails          N\A
#
#        MatNo                             Material Name  New_Volume(L)
# 1059  145577   M SUP Frict Fighter TBS 10W-30 4x7L/CAR            672
# 1771  145472  M DEL MODERN 10W-30 S DEFENS V2 4X7L/CAR            476
# 2489  145570  M SUP Friction Fighter 10W-40 4x4+1L/CAR           4320
# 3191  143629      MOBIL SUPER 2000 TBS 10W-30 4X7L/CAR           9492
# 3192  145577   M SUP Frict Fighter TBS 10W-30 4x7L/CAR           9212
# 4427  144373      MOBIL DELVAC MX 10W-30 CTN 4X6+1L:TH           6692
# 4754  145570  M SUP Friction Fighter 10W-40 4x4+1L/CAR           3760
# 4954  142923          MOBIL SPECIAL 20W-50 CTN 4X4L:TH           6544
# 5690  143629           โมบิล SUPER 2000 TBS 10W30 ,4/7           3164
# 5805  140043                  MOBIL ATF 3309 12x1L/CAR           5392
# 6572  142923             MOBIL SPECIAL 20W-50 4X4L/CAR           1104
# 6692  143160  MOBIL DELVAC SUPER1400 15W-40 4X6+1L/CAR           7336
# 6693  143877   M SUP AIO PROTECTION TBS 5W-30 4X7L/CAR          13916
# 7084  140418             MOBIL 1 TBD 5W-40 CTN 4X6L:TH           5088
# 7656  145570  M SUP Friction Fighter 10W-40 4x4+1L/CAR            600
# 7657  145828     M SUP AIO Protection 5W-40 4x4+1L/CAR           4660
# 7971  142930         MOBIL DELVAC MX 15W-40 PAIL18L:TH           8478
# 7972  142930           MOBIL DELVAC MX 15W-40 18L/PAIL           1476
# 8027  140521                 MOBIL 1 0W-40 CTN 4X4L:SG            608
# 8321  143110  MOBIL SUPER 3000 0W-20 (AIO)CTN4X3.5L:SG              7

# %% [markdown]
# Since A and B both share Bangkok and Bangkok is the highest market share, assume that all of these groupid are from Bangkok

# %%
MERT.loc[MERT['Provincename'] == 'N\A', 'Provincename'] = 'Bangkok'
MERT['Provincename'].unique()
# Out:
# array(['Chachoengsao', 'Nakhon Ratchasima', 'Nakhon Pathom', 'Phetchabun',
#        'Rayong', 'Khon Kaen', 'Trat', 'Suphan Buri', 'Lop Buri',
#        'Bangkok', 'Kanchanaburi', 'Chai Nat', 'Chon Buri', 'Phuket',
#        'Udon Thani', 'Saraburi', 'Ratchaburi', 'Nakhon Si Thammarat',
#        'Chainat', 'Chanthaburi', 'Chumphon', 'Yasothon', 'Chiang Rai',
#        'Phangnga', 'Songkhla', 'Ubon Ratchathani', 'Maha Sarakham', 'Tak',
#        'Chiang Mai', 'Samut Sakhon', 'Prachuap Khiri Khan', 'Krabi',
#        'Pathum Thani', 'Roi Et', 'Sukhothai', 'Nakhon Sawan',
#        'Surat Thani', 'Phra Nakhon Si Ayutthaya', 'Nong Bua Lam Phu',
#        'Sing Buri', 'Nakhon Phanom', 'Nakhon Nayok', 'Surin', 'Uttaradit',
#        'Lampang', 'Sa Kaeo', 'Lamphun', 'Pattani', 'Trang',
#        'Kamphaeng Phet', 'Phitsanulok', 'Uthai Thani', 'Phrae', 'Phichit',
#        'Sakon Nakhon', 'Loei', 'Nonthaburi', 'Samut Prakan', 'Nong Khai',
#        'Phetchaburi', 'Nan', 'Buri Ram', 'Si Sa Ket', 'Prachin Buri',
#        'Kalasin', 'Phatthalung', 'Chaiyaphum', 'Phayao', 'Bueng Kan',
#        'Satun', 'Mukdahan', 'Ang Thong'], dtype=object)

# %% [markdown]
# ### MatNo

# %%
MERT['MatNo'].unique()
# Out:
# array([145577, 143160, 145438, 145500, 145498, 145497, 145474, 141539,
#        143877, 143629, 145575, 142939, 145570, 143507, 142930, 140918,
#        142931, 143628, 135896, 145472, 135899, 145451, 144673, 135508,
#        145444, 134728, 145888, 140521, 140043, 145826, 137227, 145841,
#        145496, 145828, 140418, 145832, 134707, 143623, 124213, 143586,
#        135898, 135895, 137232, 142938, 144373, 143566, 135509, 143898,
#        135904, 143132, 145644, 140363, 141559, 145742, 146130, 144463,
#        142923, 134346, 137219, 145569, 139840, 135903, 144473, 123150,
#        143900, 145439, 143508, 135892, 145450, 143625, 134525, 143133,
#        143110, 143899, 135872, 140417, 143874, 144672, 134349, 134345,
#        145572, 145473, 143354, 145499, 143162, 134782, 145573, 135162,
#        142924, 145447, 143106, 143574, 134533, 142212, 145930, 140709,
#        133405, 124216, 142889, 145838, 145840, 140523, 144462, 145837,
#        140635, 143576, 145727, 143099, 145449, 142932, 139706, 139759,
#        140360, 145568, 144472, 145831, 137224, 143134, 134348, 145442,
#        140526, 137221, 140634, 140525, 145471, 142890, 145741, 141515,
#        143643, 141558, 143622, 135020, 134523, 137230, 140527, 140563,
#        142200, 143306, 141196, 143642, 143109, 145724, 142941, 138933,
#        142213])

# %% [markdown]
# ### Material Name

# %%
def extractName(series):    
    # extract viscosity, None
    name = series.name
    #pattern 1 _00w-00_
    viscosity = series.str.extract(r'\b(\d+)W-(\d+)\b') 
    #pattern 2 -00w00-
    viscosity.loc[(viscosity.isna().all(axis=1))] = series[viscosity.isna().all(axis=1)].str.extract(r'(\d{2})W(\d{2})')
    #pattern 3 _00w00_
    viscosity.loc[(viscosity.isna().all(axis=1))] = series[viscosity.isna().all(axis=1)].str.extract(r'\b(\d+)W(\d+)\b')
    #pattern 4 00w-00
    viscosity.loc[(viscosity.isna().all(axis=1))] = series[viscosity.isna().all(axis=1)].str.extract(r'(\d+)W-(\d+)')
    
    # if any pattern is found
    value = viscosity.dropna()
    if value.empty:
        finalVis = np.nan
    else:
        finalVis = (value[0].astype(str) + "w-" + value[1].astype(str)).values[0]


    # special pattern single w: 10w
    if finalVis is np.nan:
        specialVis = series.str.extract(r'\b(\d+)W\b')
        
        specialVisvalue = specialVis.dropna()

        if not specialVisvalue.empty:
            finalVis = str(specialVisvalue.values[0][0]) + "w"

    # isDelvac: True, or False

    #pattern: contain Del (case insensitive)
    containDel = series.str.contains('del', case=False).any()
    if containDel:
        finalDel = True
    else:
        finalDel = False


    # product line: super, one, None
    containSuper = series.str.contains('sup', case=False).any()
    containOne = series.str.contains(r'.*\b1\b.*',regex=True).any()


    if containSuper:
        finalLine = "Super"
    elif containOne:
        finalLine = "One"
    else:
        finalLine = np.nan

    # product group name: just select one
    groupName = series.values[0]
    

    cols = ['Viscosity', 'isDelvac', 'ProductLine', 'GroupName']
    
    return pd.Series((finalVis, finalDel, finalLine, groupName), index=cols)
    




pd.set_option('display.max_colwidth', None)
MaterialTable = MERT.groupby('MatNo')['Material Name'].apply(extractName).unstack(-1)

# %%
MaterialTable
# Out:
#        Viscosity isDelvac ProductLine                               GroupName
# MatNo
# 123150       NaN    False         NaN        MOBIL MULTIPURPOSE ATF, 208LT DR
# 124213       NaN    False         NaN                  MOBIL ATF 220  D 208LT
# 124216       NaN    False         NaN                   MOBIL ATF 220 P1/20LT
# 133405    20w-50     True       Super   MOBIL DELVAC SUPER 20W-50, 12X1LT CTN
# 134345       10w    False         NaN          MOBIL HYDRAULIC 10W, 4X5LT CTN
# ...          ...      ...         ...                                     ...
# 145840     0w-40    False         One         MOBIL 1 0W-40 (SP) V2 12X1L/CAR
# 145841     0w-40    False         One          MOBIL 1 0W-40 (SP) V2 4X4L/CAR
# 145888    20w-50    False       Super  M SUP EVD Protection 20W-50 4x4+1L/CAR
# 145930    10w-30    False       Super            M SUPER FF 10W-30, 4X4LT CTN
# 146130     0w-40    False         One               MOBIL 1 0W-40 V3 4X4L/CAR
#
# [145 rows x 4 columns]

# %%
MaterialTable[MaterialTable["ProductLine"].isna()]
# Out:
#        Viscosity isDelvac ProductLine  \
# MatNo
# 123150       NaN    False         NaN
# 124213       NaN    False         NaN
# 124216       NaN    False         NaN
# 134345       10w    False         NaN
# 134348       NaN    False         NaN
# 134533       NaN     True         NaN
# 134782       NaN     True         NaN
# 135162       NaN    False         NaN
# 135508       NaN     True         NaN
# 135895   85w-140    False         NaN
# 135898    80w-90    False         NaN
# 135903    80w-90    False         NaN
# 137221    15w-40     True         NaN
# 140709    15w-40     True         NaN
# 140918    15w-40    False         NaN
# 142200       NaN    False         NaN
# 142889    10w-30     True         NaN
# 142890    10w-30     True         NaN
# 142923    20w-50    False         NaN
# 142930    15w-40     True         NaN
# 143900       NaN    False         NaN
# 144373    10w-30     True         NaN
# 145438    20w-50     True         NaN
# 145439       NaN     True         NaN
# 145444       NaN     True         NaN
# 145447       NaN     True         NaN
# 145449       NaN     True         NaN
# 145451    20w-50     True         NaN
# 145497    15w-40     True         NaN
# 145498    15w-40     True         NaN
# 145499    10w-30     True         NaN
#
#                                        GroupName
# MatNo
# 123150          MOBIL MULTIPURPOSE ATF, 208LT DR
# 124213                    MOBIL ATF 220  D 208LT
# 124216                     MOBIL ATF 220 P1/20LT
# 134345            MOBIL HYDRAULIC 10W, 4X5LT CTN
# 134348       MOBIL BRAKE FLUID DOT-4 12X0.5L/CAR
# 134533                  MOBIL DELVAC 1330, P18LT
# 134782              MOBIL DELVAC 1340, 4X6LT CTN
# 135162                  MOBILFLUID 424, 20L PAIL
# 135508          MOBIL DELVAC 1640, 4X6LT CTN - N
# 135895                MOBILUBE HD 85W-140 4/5 LT
# 135898                 MOBILUBE HD 80W-90 4/5 LT
# 135903         MOBILUBE GX80W-90 GL-4, 4x5LT CTN
# 137221   MOBIL DELVAC MX15W-40, 12X1LT, CI-4 NEW
# 140709          MOBIL DELVAC MX ESP 15W-40, 20LT
# 140918                 MOBIL GEO 15W-40 18L/PAIL
# 142200                MOBIL ATF 3324 CTN 4x4L:TH
# 142889        MOBIL DELVAC MX 10W-30 CTN 4X6L:TH
# 142890       MOBIL DELVAC MX 10W-30 CTN 12X1L:TH
# 142923             MOBIL SPECIAL 20W-50 4X4L/CAR
# 142930           MOBIL DELVAC MX 15W-40 18L/PAIL
# 143900           MOBIL ATF 220 SYN TECH 4X5L/CAR
# 144373      MOBIL DELVAC MX 10W-30 CTN 4X6+1L:TH
# 145438              M-Del Legend 20W50 S Def,20L
# 145439     MOBIL DELVAC LEGEND 1640, 1X20LT PAIL
# 145444   MOBIL DELVAC LEGEND 1640, 4X6LT CTN - N
# 145447           MOBIL DELVAC LEGEND 1330, P18LT
# 145449         MOBIL DELVAC LEGEND 1340 20L/PAIL
# 145451   M DEL LEGEND 20W-50 STD DEFENS 4X6L/CAR
# 145497     M DEL LEGEND CH-4 15W-40 HD. 4X7L/CAR
# 145498     M DEL LEGEND CH-4 15W-40 HD. 20L/PAIL
# 145499  M DEL MODERN 10W-30 S DEFENS V2 20L/PAIL
